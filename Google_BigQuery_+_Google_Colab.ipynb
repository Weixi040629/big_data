# %% [markdown]
# <a href="https://colab.research.google.com/github/Weixi040629/big_data/blob/main/Google_BigQuery_%2B_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Provide your credentials to the runtime

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# ## Enable data table display
#
# Colab includes the ``google.colab.data_table`` package that can be used to display large pandas dataframes as an interactive data table.
# It can be enabled with:

# %%
# %load_ext google.colab.data_table

# %% [markdown]
# If you would prefer to return to the classic Pandas dataframe display, you can disable this by running:
# ```python
# %unload_ext google.colab.data_table
# ```

# %% [markdown]
# # Use BigQuery via magics
#
# The `google.cloud.bigquery` library also includes a magic command which runs a query and either displays the result or saves it to a variable as a `DataFrame`.

# %%
# Display query output immediately

# %%bigquery --project ambient-scope-319223
SELECT 
  COUNT(*) as total_rows
FROM `bigquery-public-data.samples.gsod`
# Out:
#    total_rows
# 0   114420316

# %% [markdown]
# ## Show the 100 rows of the table we are looking at

# %%
# %%bigquery --project ambient-scope-319223
# SELECT
# *
# FROM `bigquery-public-data.samples.github_timeline`
# LIMIT 100
# Out:
#                                  repository_url  ...       type
# 0        https://github.com/visionmedia/express  ...  ForkEvent
# 1           https://github.com/ksky521/webSlide  ...  ForkEvent
# 2         https://github.com/mozilla/openbadges  ...  ForkEvent
# 3                    https://github.com/pry/pry  ...  ForkEvent
# 4     https://github.com/springside/springside4  ...  ForkEvent
# ..                                          ...  ...        ...
# 95     https://github.com/kirbyt/KTPhotoBrowser  ...  ForkEvent
# 96            https://github.com/madrobby/zepto  ...  ForkEvent
# 97       https://github.com/octocat/Spoon-Knife  ...  ForkEvent
# 98         https://github.com/diaspora/diaspora  ...  ForkEvent
# 99  https://github.com/documentcloud/underscore  ...  ForkEvent
#
# [100 rows x 199 columns]

# %%
# %%bigquery --project ambient-scope-319223
#
# SELECT type
# FROM `bigquery-public-data.samples.github_timeline`
# group by 1
# Out:
#                              type
# 0                       ForkEvent
# 1                       PushEvent
# 2                      WatchEvent
# 3                     CreateEvent
# 4                     DeleteEvent
# 5                     GollumEvent
# 6                     IssuesEvent
# 7                     MemberEvent
# 8                     PublicEvent
# 9                   DownloadEvent
# 10                 ForkApplyEvent
# 11               PullRequestEvent
# 12              IssueCommentEvent
# 13             CommitCommentEvent
# 14  PullRequestReviewCommentEvent
# 15                           None
# 16                      GistEvent
# 17                    FollowEvent

# %% [markdown]
# ## In your groups, write a queries to show:
# 1. Which repository has the most watchers?
# 2. Name all of the types of events (field: type) in this table
# 3. Which year were the most repositories created?
# 4. How many repositories had downloads? How many repositories did not have downloads?
